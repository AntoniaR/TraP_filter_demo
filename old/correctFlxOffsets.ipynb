# %% [markdown]
# # A code to correct any systemmatic flux density offsets in radio images.
# First run TraP on the images with a high detection threshold to get bright sources.
# Then run this script to obtain the multiplicative flux density correction for each individual image.
# It compares the extracted flux density to the average flux density for each source, by fitting a straight line between the datapoints, the gradient gives the multiplicative flux density factor.
# The key assumption is that the majority of sources are stable.
#
# Advice for use
#  - select bright, point-like sources within the FWHM of the beam.
#  - Use the TraP monitoring list capability (with a very high detection threshold) to only get the sources chosen
#
#  note - only process one frequency at once

# %%
import scipy as sp
import numpy as np
import pandas as pd
import sqlalchemy
from sqlalchemy import *
from sqlalchemy.orm import relationship
import tkp.db
import sys
from dblogin import * # This file contains all the variables required to connect to the database
import matplotlib
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['legend.loc'] = 'best'
from matplotlib.ticker import NullFormatter
from matplotlib.font_manager import FontProperties
from astropy.io import fits

# %%
# The input database, dataset and thresholds
dataset_id = 43
database = 'antoniar'
plots=False
saveFigUrl='/scratch/antoniar/ELAIS_flxcorr/'

# %%
# Connect to the database and run the queries
db = tkp.db.Database(engine=engine, host=host, port=port, user=user, password=password, database=database)
db.connect()
session = db.Session()
# Out:
# Not configuring pre-configured database

# %%
# Obtain the average flux density measurement for each source
# RuncatID, Avg Int Flux Density
from tkp.db.model import Runningcatalog
from tkp.db.model import RunningcatalogFlux

Runcats = session.query(Runningcatalog,RunningcatalogFlux).select_from(join(Runningcatalog,RunningcatalogFlux)).filter(Runningcatalog.dataset_id == dataset_id).all()
RuncatsData=[[Runcats[i].Runningcatalog.id,Runcats[i].RunningcatalogFlux.avg_f_int,Runcats[i].Runningcatalog.datapoints] for i in range(len(Runcats))]
RuncatsData = pd.DataFrame(data=RuncatsData, columns=['RuncatID','avg_f_int','datapoints'])
print(RuncatsData)
# Out:
#      RuncatID  avg_f_int  datapoints
# 0       72678   0.006501          50
# 1       72517   0.020591          52
# 2       72581   0.004766          51
# 3       72648   0.004641          51
# 4       72736   0.208109          60
# ..        ...        ...         ...
# 396     72458   0.047843          60
# 397     72622   0.010380          59
# 398     72650   0.026305          60
# 399     72530   0.040964          60
# 400     72608   0.031722          60
#
# [401 rows x 3 columns]

# %%
# Get all the extracted sources with their runcat ids

from tkp.db.model import Assocxtrsource

listRuncats = RuncatsData.RuncatID
listRuncats = list(listRuncats)
listRuncats.sort()
AssocSrcs = session.query(Assocxtrsource).filter(Assocxtrsource.runcat_id.in_(listRuncats)).all()
AssocSrcs = [[AssocSrcs[i].xtrsrc.id, AssocSrcs[i].runcat.id] for i in range(len(AssocSrcs))]
AssocSrcs = pd.DataFrame(data=AssocSrcs, columns=['xtrsrc','RuncatID'])
print(AssocSrcs)
# Out:
#         xtrsrc  RuncatID
# 0      1526669     72440
# 1      1526670     72441
# 2      1526671     72442
# 3      1526672     72443
# 4      1526673     72444
# ...        ...       ...
# 21719  1548285     72809
# 21720  1548286     72811
# 21721  1548287     72818
# 21722  1548288     72819
# 21723  1548289     72833
#
# [21724 rows x 2 columns]

# %%
# Loop through the images

from tkp.db.model import Image

Images = session.query(Image).filter(Image.dataset_id == dataset_id).all()
numImgs=len(Images)

print(numImgs)
# Out:
# 72

# %%
# For each image obtain the extracted source flux density for each RuncatID
    
from tkp.db.model import Extractedsource

for a in range(len(Images)):
    extractedSrcs = session.query(Extractedsource).filter(Extractedsource.image_id == Images[a].id).all()
    extractedSrcsData = [[extractedSrcs[b].id,extractedSrcs[b].f_int,extractedSrcs[b].f_int_err] for b in range(len(extractedSrcs))]
    extractedSrcsData = pd.DataFrame(data=extractedSrcsData, columns=['xtrsrc','f_int','f_int_err'])
    extractedSrcsData = pd.merge(extractedSrcsData,AssocSrcs, on='xtrsrc')
    plotData = pd.merge(extractedSrcsData,RuncatsData,on='RuncatID')

    # Fit straight line through the origin and output the gradient
    x=np.array(plotData.avg_f_int)
    y=np.array(plotData.f_int)

    if len(x) > 0:
        x = x[:,np.newaxis]
        b, _, _, _ = np.linalg.lstsq(x,y,rcond=None) # fit a straight line going through the origin   
        print(Images[a].url, b[0])
        xrng = np.linspace(0,max(plotData.avg_f_int),10)
        xfit = [x*b for x in xrng]
        if plots==True:
            # Plot scatter graph of data points
            plt.errorbar(plotData.avg_f_int, plotData.f_int, yerr=plotData.f_int_err, fmt='o')
            plt.plot(xrng,xfit,'-')
            plt.show()
        
        #Open each image and multiply the pixel values by the gradient - save each image to new location
        hdu = fits.open(Images[a].url)
        data = hdu[0].data[0][0]
        hdu[0].data[0][0] = data / b[0]
        newFilename = Images[a].url.split('/')[-1]
        newFilename = saveFigUrl+'corrected_'+newFilename
        hdu.writeto(newFilename)
# Out:
# /scratch/ideruiter/deep_fields_individual_epochs/L229064_image_full_ampphase_di_m.NS.app.restored.fits 1.1735603865775592
# /scratch/ideruiter/deep_fields_individual_epochs/L229312_image_full_ampphase_di_m.NS.app.restored.fits 1.1684889467869497
# /scratch/ideruiter/deep_fields_individual_epochs/L229387_image_full_ampphase_di_m.NS.app.restored.fits 1.156320814786933
# /scratch/ideruiter/deep_fields_individual_epochs/L229673_image_full_ampphase_di_m.NS.app.restored.fits 1.1669130024214924
# /scratch/ideruiter/deep_fields_individual_epochs/L230461_image_full_ampphase_di_m.NS.app.restored.fits 1.1728230623725007
# /scratch/ideruiter/deep_fields_individual_epochs/L230779_image_full_ampphase_di_m.NS.app.restored.fits 1.1561814130377934
# /scratch/ideruiter/deep_fields_individual_epochs/L231211_image_full_ampphase_di_m.NS.app.restored.fits 1.1440901256561926
# /scratch/ideruiter/deep_fields_individual_epochs/L231505_image_full_ampphase_di_m.NS.app.restored.fits 1.0918544478112528
# /scratch/ideruiter/deep_fields_individual_epochs/L231647_image_full_ampphase_di_m.NS.app.restored.fits 1.1315753466593883
# /scratch/ideruiter/deep_fields_individual_epochs/L232981_image_full_ampphase_di_m.NS.app.restored.fits 1.1434757378700888
# /scratch/ideruiter/deep_fields_individual_epochs/L345624_image_full_ampphase_di_m.NS.app.restored.fits 0.8673503836983391
# /scratch/ideruiter/deep_fields_individual_epochs/L346136_image_full_ampphase_di_m.NS.app.restored.fits 0.8651864968537487
# /scratch/ideruiter/deep_fields_individual_epochs/L346454_image_full_ampphase_di_m.NS.app.restored.fits 0.7690833570704729
# /scratch/ideruiter/deep_fields_individual_epochs/L347030_image_full_ampphase_di_m.NS.app.restored.fits 0.9178729430370982
# /scratch/ideruiter/deep_fields_individual_epochs/L347404_image_full_ampphase_di_m.NS.app.restored.fits 0.830674125966717
# /scratch/ideruiter/deep_fields_individual_epochs/L347494_image_full_ampphase_di_m.NS.app.restored.fits 0.8578435583186542
# /scratch/ideruiter/deep_fields_individual_epochs/L347512_image_full_ampphase_di_m.NS.app.restored.fits 0.9101816319243311
# /scratch/ideruiter/deep_fields_individual_epochs/L348512_image_full_ampphase_di_m.NS.app.restored.fits 0.9514131314687985
# /scratch/ideruiter/deep_fields_individual_epochs/L351576_image_full_ampphase_di_m.NS.app.restored.fits 0.9099542425004992
# /scratch/ideruiter/deep_fields_individual_epochs/L366792_image_full_ampphase_di_m.NS.app.restored.fits 0.9615556449577674
# /scratch/ideruiter/deep_fields_individual_epochs/L369548_image_full_ampphase_di_m.NS.app.restored.fits 0.9005300234637876
# /scratch/ideruiter/deep_fields_individual_epochs/L369530_image_full_ampphase_di_m.NS.app.restored.fits 0.9017597263472038
# /scratch/ideruiter/deep_fields_individual_epochs/L687004_image_full_ampphase_di_m.NS.app.restored.fits 0.782120105146094
# /scratch/ideruiter/deep_fields_individual_epochs/L686990_image_full_ampphase_di_m.NS.app.restored.fits 0.8278295625950508
# /scratch/ideruiter/deep_fields_individual_epochs/L686976_image_full_ampphase_di_m.NS.app.restored.fits 0.8332709041361339
# /scratch/ideruiter/deep_fields_individual_epochs/L686962_image_full_ampphase_di_m.NS.app.restored.fits 1.1636953639507273
# /scratch/ideruiter/deep_fields_individual_epochs/L686948_image_full_ampphase_di_m.NS.app.restored.fits 1.1375166616393275
# /scratch/ideruiter/deep_fields_individual_epochs/L686920_image_full_ampphase_di_m.NS.app.restored.fits 1.130080977869706
# /scratch/ideruiter/deep_fields_individual_epochs/L686892_image_full_ampphase_di_m.NS.app.restored.fits 1.0924405483468576
# /scratch/ideruiter/deep_fields_individual_epochs/L686906_image_full_ampphase_di_m.NS.app.restored.fits 0.7987482013340312
# /scratch/ideruiter/deep_fields_individual_epochs/L710174_image_full_ampphase_di_m.NS.app.restored.fits 1.1565903089793586
# /scratch/ideruiter/deep_fields_individual_epochs/L716768_image_full_ampphase_di_m.NS.app.restored.fits 0.8247858542749278
# /scratch/ideruiter/deep_fields_individual_epochs/L716750_image_full_ampphase_di_m.NS.app.restored.fits 0.834564479250956
# /scratch/ideruiter/deep_fields_individual_epochs/L716732_image_full_ampphase_di_m.NS.app.restored.fits 0.8328437096576953
# /scratch/ideruiter/deep_fields_individual_epochs/L716714_image_full_ampphase_di_m.NS.app.restored.fits 0.8527862642040324
# /scratch/ideruiter/deep_fields_individual_epochs/L760853_image_full_ampphase_di_m.NS.app.restored.fits 0.8432346821462616
# /scratch/ideruiter/deep_fields_individual_epochs/L769435_image_full_ampphase_di_m.NS.app.restored.fits 0.8427975376679517
# /scratch/ideruiter/deep_fields_individual_epochs/L769421_image_full_ampphase_di_m.NS.app.restored.fits 0.872610297186347
# /scratch/ideruiter/deep_fields_individual_epochs/L769393_image_full_ampphase_di_m.NS.app.restored.fits 0.8489261673682859
# /scratch/ideruiter/deep_fields_individual_epochs/L782679_image_full_ampphase_di_m.NS.app.restored.fits 0.7931129738512568
# /scratch/ideruiter/deep_fields_individual_epochs/L798022_image_full_ampphase_di_m.NS.app.restored.fits 0.9632135931311347
# /scratch/ideruiter/deep_fields_individual_epochs/L798074_image_full_ampphase_di_m.NS.app.restored.fits 0.9752199932496929
# /scratch/ideruiter/deep_fields_individual_epochs/L798092_image_full_ampphase_di_m.NS.app.restored.fits 0.9779275729479809
# /scratch/ideruiter/deep_fields_individual_epochs/L798110_image_full_ampphase_di_m.NS.app.restored.fits 1.2797911374509963
# /scratch/ideruiter/deep_fields_individual_epochs/L798128_image_full_ampphase_di_m.NS.app.restored.fits 1.3283073205519076
# /scratch/ideruiter/deep_fields_individual_epochs/L798146_image_full_ampphase_di_m.NS.app.restored.fits 1.3166848036248566
# /scratch/ideruiter/deep_fields_individual_epochs/L798164_image_full_ampphase_di_m.NS.app.restored.fits 0.9725835382154113
# /scratch/ideruiter/deep_fields_individual_epochs/L811718_image_full_ampphase_di_m.NS.app.restored.fits 1.3664879589499161
# /scratch/ideruiter/deep_fields_individual_epochs/L811736_image_full_ampphase_di_m.NS.app.restored.fits 1.3728218845612559
# /scratch/ideruiter/deep_fields_individual_epochs/L816272_image_full_ampphase_di_m.NS.app.restored.fits 0.9966121380188075
# /scratch/ideruiter/deep_fields_individual_epochs/L816290_image_full_ampphase_di_m.NS.app.restored.fits 1.0091973647521821
# /scratch/ideruiter/deep_fields_individual_epochs/L816308_image_full_ampphase_di_m.NS.app.restored.fits 0.9976072661021584
# /scratch/ideruiter/deep_fields_individual_epochs/L816326_image_full_ampphase_di_m.NS.app.restored.fits 0.9929574122984192
# /scratch/ideruiter/deep_fields_individual_epochs/L816344_image_full_ampphase_di_m.NS.app.restored.fits 0.9682890504831757
# /scratch/ideruiter/deep_fields_individual_epochs/L816362_image_full_ampphase_di_m.NS.app.restored.fits 0.9853555418139959
# /scratch/ideruiter/deep_fields_individual_epochs/L818936_image_full_ampphase_di_m.NS.app.restored.fits 1.0021768923519603
# /scratch/ideruiter/deep_fields_individual_epochs/L818954_image_full_ampphase_di_m.NS.app.restored.fits 0.9350020593816378
# /scratch/ideruiter/deep_fields_individual_epochs/L825970_image_full_ampphase_di_m.NS.app.restored.fits 0.9500051102284627
# /scratch/ideruiter/deep_fields_individual_epochs/L833466_image_full_ampphase_di_m.NS.app.restored.fits 0.9844115364125638
# /scratch/ideruiter/deep_fields_individual_epochs/L833448_image_full_ampphase_di_m.NS.app.restored.fits 1.0099028642117112
